# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('..\data\sales.xlsx - Orders.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Wayne\AppData\Local\Temp\ipykernel_32348\1365023424.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df=pd.read_csv('..\data\sales.xlsx - Orders.csv')

# %%
df.head(2)
# Out:
#    Row ID  Order ID  Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3  10/13/2010            Low               6    261.54
# 1      49       293   10/1/2012           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin   Ship Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                8399 non-null   int64
#  1   Order ID              8399 non-null   int64
#  2   Order Date            8399 non-null   object
#  3   Order Priority        8399 non-null   object
#  4   Order Quantity        8399 non-null   int64
#  5   Sales                 8399 non-null   float64
#  6   Discount              8399 non-null   float64
#  7   Ship Mode             8399 non-null   object
#  8   Profit                8399 non-null   float64
#  9   Unit Price            8399 non-null   float64
#  10  Shipping Cost         8399 non-null   float64
#  11  Customer Name         8399 non-null   object
#  12  Province              8399 non-null   object
#  13  Region                8399 non-null   object
#  14  Customer Segment      8399 non-null   object
# ...

# %%
df.describe(include='all')
# Out:
#              Row ID      Order ID Order Date Order Priority  Order Quantity  \
# count   8399.000000   8399.000000       8399           8399     8399.000000
# unique          NaN           NaN       1418              5             NaN
# top             NaN           NaN  3/28/2012           High             NaN
# freq            NaN           NaN         20           1768             NaN
# mean    4200.000000  29965.179783        NaN            NaN       25.571735
# std     2424.726789  17260.883447        NaN            NaN       14.481071
# min        1.000000      3.000000        NaN            NaN        1.000000
# 25%     2100.500000  15011.500000        NaN            NaN       13.000000
# 50%     4200.000000  29857.000000        NaN            NaN       26.000000
# 75%     6299.500000  44596.000000        NaN            NaN       38.000000
# max     8399.000000  59973.000000        NaN            NaN       50.000000
#
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Row ID                   0
# Order ID                 0
# Order Date               0
# Order Priority           0
# Order Quantity           0
# Sales                    0
# Discount                 0
# Ship Mode                0
# Profit                   0
# Unit Price               0
# Shipping Cost            0
# Customer Name            0
# Province                 0
# Region                   0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Name             0
# Product Container        0
# Product Base Margin     63
# Ship Date                0
# dtype: int64

# %%
# Check for duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# View column names
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %% [markdown]
# #### Data Cleaning

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
# Handle missing values
# Example: Fill numerical columns with median & categorical with mode
for col in df.columns:
    if df[col].dtype in ['int64', 'float64']:
        df[col].fillna(df[col].median(), inplace=True)
    else:
        df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# C:\Users\Wayne\AppData\Local\Temp\ipykernel_32348\2373917101.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\Wayne\AppData\Local\Temp\ipykernel_32348\2373917101.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %% [markdown]
# #### Date Type Conversion

# %%
# Example: Convert date column if exists
if 'order_date' in df.columns:
    df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# %%
# outlier detection and handling
# Example: Remove extreme outliers in numerical columns
num_cols = df.select_dtypes(include=[np.number]).columns
for col in num_cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# %%
df.isnull().sum()
# Out:
# row_id                  0
# order_id                0
# order_date              0
# order_priority          0
# order_quantity          0
# sales                   0
# discount                0
# ship_mode               0
# profit                  0
# unit_price              0
# shipping_cost           0
# customer_name           0
# province                0
# region                  0
# customer_segment        0
# product_category        0
# product_sub-category    0
# product_name            0
# product_container       0
# product_base_margin     0
# ship_date               0
# dtype: int64

# %%
cleaned_file_path = "../data/sales_cleaned.csv"
df.to_csv(cleaned_file_path, index=False)
